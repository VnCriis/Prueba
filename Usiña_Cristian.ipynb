# %%
import pandas as pd
df = pd.read_csv('caso3.csv') 
df_sin_ceros= df[df[''] != 0]
# Out:
#         VIN (1-10)     County        City State  Postal Code  Model Year  \
# 0       3C3CFFGE4E     Yakima      Yakima    WA      98902.0        2014
# 1       5YJXCBE40H   Thurston     Olympia    WA      98513.0        2017
# 2       3MW39FS03P       King      Renton    WA      98058.0        2023
# 3       7PDSGABA8P  Snohomish     Bothell    WA      98012.0        2023
# 4       5YJ3E1EB8L       King        Kent    WA      98031.0        2020
# ...            ...        ...         ...   ...          ...         ...
# 166795  3FA6P0SU4D    Spokane     Spokane    WA      99223.0        2013
# 166796  5YJYGDEE5M       King   Sammamish    WA      98074.0        2021
# 166797  7SAYGDEE5N  Snohomish    Mukilteo    WA      98275.0        2022
# 166798  1G1RH6E43D      Lewis   Mossyrock    WA      98564.0        2013
# 166799  5YJSA1E27H     Pierce  Gig Harbor    WA      98332.0        2017
#
#              Make    Model                   Electric Vehicle Type  \
# ...

# %%
import pandas as pd
df = pd.read_csv('caso3.csv')
df = df.dropna() 
df
# Out:
#         VIN (1-10)     County        City State  Postal Code  Model Year  \
# 0       3C3CFFGE4E     Yakima      Yakima    WA      98902.0        2014
# 1       5YJXCBE40H   Thurston     Olympia    WA      98513.0        2017
# 2       3MW39FS03P       King      Renton    WA      98058.0        2023
# 3       7PDSGABA8P  Snohomish     Bothell    WA      98012.0        2023
# 4       5YJ3E1EB8L       King        Kent    WA      98031.0        2020
# ...            ...        ...         ...   ...          ...         ...
# 166795  3FA6P0SU4D    Spokane     Spokane    WA      99223.0        2013
# 166796  5YJYGDEE5M       King   Sammamish    WA      98074.0        2021
# 166797  7SAYGDEE5N  Snohomish    Mukilteo    WA      98275.0        2022
# 166798  1G1RH6E43D      Lewis   Mossyrock    WA      98564.0        2013
# 166799  5YJSA1E27H     Pierce  Gig Harbor    WA      98332.0        2017
#
#              Make    Model                   Electric Vehicle Type  \
# ...

# %%
import matplotlib.pyplot as plt
df = pd.read_csv('caso3.csv')
plt.scatter(df_sin_ceros['Base MSRP'], df_sin_ceros['Electric Range'], alpha=0.5, color='red')
plt.xlabel('Precio Base')
plt.ylabel('Rango Eléctrico')
plt.title('Diagrama entre  Relación entre Rango Eléctrico y Precio Base')
plt.show()

# %%
plt.figure(figsize=(10, 6))
df['Make'].value_counts().plot(kind='bar', color='green')
plt.xlabel('Marca')
plt.ylabel('Cantidad de Vehículos')
plt.title('Cantidad de Vehículos por Marca')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
cafv_eligible_ratio = df['Clean Alternative Fuel Vehicle (CAFV) Eligibility'].value_counts(normalize=True) * 100
cafv_eligible_ratio.plot(kind='bar', color='green')
plt.xlabel('Elegibilidad para CAFV')
plt.ylabel('Porcentaje')
plt.title('Proporción de Vehículos Elegibles para CAFV')
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')

xs = df_sin_ceros['Electric Range']
ys = df_sin_ceros['Base MSRP']
zs = df_sin_ceros['Model Year']

ax.scatter(xs, ys, zs, c='b', marker='o')

ax.set_xlabel('Rango Eléctrico')
ax.set_ylabel('Precio Base')
ax.set_zlabel('Año del Modelo')

plt.show()

# %%
marca_counts = df_sin_ceros['Make'].value_counts()

plt.figure(figsize=(10, 6))
plt.pie(marca_counts, labels=marca_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribución de Vehículos por Marca')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

tipo_counts = df_sin_ceros['Electric Vehicle Type'].value_counts()

plt.figure(figsize=(10, 6))
plt.pie(tipo_counts, labels=tipo_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribución de Tipos de Vehículos Eléctricos')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt


plt.figure(figsize=(10, 6))
sns.histplot(df_sin_ceros_precio['Base MSRP'], bins=20, kde=True, color='lightcoral')
plt.xlabel('Precio Base')
plt.ylabel('Frecuencia')
plt.title('Distribución de Precios Base de los Vehículos')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Legislative District'], bins=20, kde=True, color='orange')
plt.xlabel('Distrito Legislativo')
plt.ylabel('Frecuencia')
plt.title('Distribución del Distrito Legislativo de los Vehículos')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.countplot(data=df, x='Make', hue='Electric Vehicle Type', palette='coolwarm')
plt.xlabel('Marca')
plt.ylabel('Cantidad de Vehículos')
plt.title('Cantidad de Vehículos Eléctricos y Plug-in Híbridos por Marca')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Tipo de Vehículo', loc='upper right')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

resumen_df = df.groupby(['Make', 'Electric Vehicle Type']).size().unstack(fill_value=0).reset_index()

# Grafico de barras apiladas
plt.figure(figsize=(12, 8))
sns.barplot(x='Make', y='Battery Electric Vehicle (BEV)', data=resumen_df, color='skyblue', label='Vehículos Eléctricos')
sns.barplot(x='Make', y='Plug-in Hybrid Electric Vehicle (PHEV)', data=resumen_df, color='orange', bottom=resumen_df['Battery Electric Vehicle (BEV)'], label='Vehículos Plug-in Híbridos')

plt.xlabel('Marca')
plt.ylabel('Cantidad de Vehículos')
plt.title('Comparación de Vehículos Eléctricos y Plug-in Híbridos por Marca')
plt.xticks(rotation=45, ha='right')
plt.legend()

plt.show()
